# %% [markdown]
# <a href="https://colab.research.google.com/github/tnc1/ai-ml/blob/main/day10_task7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
  TASK 7 — FINAL ANALYSIS QUESTIONS
    Answer the following:
      1. Which AI model was used for:
        ○ prediction?
          Linear Regression
        ○ classification?
          Logistic Regression
        ○ clustering?
          K-Means
        ○ image recognition?
          Convolutional Neural Networks (CNN)

      2. Why is preprocessing important in AI projects?
        Preprocessing of data is important in AI projects in order to improve overall prediction quality.
      3. Why can AI predictions sometimes be incorrect?
        Poor trainin data quality and/or wrong prompts.
      4. What is the difference between:
        ○ Linear Regression
          Is used to predict numerical data.
        ○ Logistic Regression
          Is used to preduct categorical data.
        ○ K-Means Clustering
          Is used to categorize data in groups.
      5. Which module did you find most useful and why?
        I found Natural Language Toolkit useful because I can easily use it for future projects for sentiment analysis.
"""
